# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_cidades = pd.read_excel('csv/apuracaoCidade_1_e_2.xls')
df_cidades.head()
# Out:
#    uf   cid          nome  urnas_1  urnas_2       ultimo_voto_1  \
# 0  AC  1120    ACRELANDIA       42       42 2022-10-02 15:39:28
# 1  AC  1570  ASSIS BRASIL       23       23 2022-10-02 16:54:28
# 2  AC  1058     BRASILEIA       71       71 2022-10-02 16:28:40
# 3  AC  1007        BUJARI       35       35 2022-10-02 16:17:51
# 4  AC  1015      CAPIXABA       31       31 2022-10-02 16:37:52
#
#         ultimo_voto_2  aptos_1  aptos_2  faltou_1  ...  voto_transito_1  \
# 0 2022-10-30 15:18:39     9521     9522      2228  ...                0
# 1 2022-10-30 15:16:04     6390     6389      1371  ...                1
# 2 2022-10-30 15:11:38    18195    18197      3658  ...                3
# 3 2022-10-30 15:17:49     9947     9948      2415  ...                0
# 4 2022-10-30 15:15:11     7836     7836      1670  ...                0
#
#    voto_transito_2  voto_justificado_1  voto_justificado_2  \
# 0                0                 244                 233
# ...

# %%
df_cidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   uf                            5570 non-null   object
#  1   cid                           5570 non-null   int64
#  2   nome                          5570 non-null   object
#  3   urnas_1                       5570 non-null   int64
#  4   urnas_2                       5570 non-null   int64
#  5   ultimo_voto_1                 5570 non-null   datetime64[ns]
#  6   ultimo_voto_2                 5570 non-null   datetime64[ns]
#  7   aptos_1                       5570 non-null   int64
#  8   aptos_2                       5570 non-null   int64
#  9   faltou_1                      5570 non-null   int64
#  10  faltou_2                      5570 non-null   int64
#  11  total_eleitores_log_1         5570 non-null   int64
# ...

# %%
regiao_metropolitana = ['JOAO PESSOA', 'BAYEUX', 
                        'SANTA RITA', 'CABEDELO',
                        'PEDRAS DE FOGO', 'CONDE',
                        'RIO TINTO','CAAPORA',
                        'ALHANDRA', 'PITIMBU',
                        'CRUZ DO ESPIRITO SANTO', 'LUCENA']

df_regiao_metropolitana = df_cidades[(df_cidades['uf'] == 'PB') & 
                                     (df_cidades['nome'].isin(regiao_metropolitana))]

df_regiao_metropolitana.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 2569 to 2732
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   uf                            12 non-null     object
#  1   cid                           12 non-null     int64
#  2   nome                          12 non-null     object
#  3   urnas_1                       12 non-null     int64
#  4   urnas_2                       12 non-null     int64
#  5   ultimo_voto_1                 12 non-null     datetime64[ns]
#  6   ultimo_voto_2                 12 non-null     datetime64[ns]
#  7   aptos_1                       12 non-null     int64
#  8   aptos_2                       12 non-null     int64
#  9   faltou_1                      12 non-null     int64
#  10  faltou_2                      12 non-null     int64
#  11  total_eleitores_log_1         12 non-null     int64
# ...

# %%
abstencao_1 = sns.barplot(x='faltou_1', y='nome', data=df_regiao_metropolitana, orient='h', ascending=False)
plt.title('Abstenção na Região Metropolitana de João Pessoa - 1º Turno')
# Out:
# Text(0.5, 1.0, 'Abstenção na Região Metropolitana de João Pessoa - 1º Turno')

# %%
abstencao_2 = sns.barplot(x='faltou_2', y='nome', data=df_regiao_metropolitana, orient='h')
plt.title('Abstenção na Região Metropolitana de João Pessoa - 2º Turno')
# Out:
# Text(0.5, 1.0, 'Abstenção na Região Metropolitana de João Pessoa - 2º Turno')
